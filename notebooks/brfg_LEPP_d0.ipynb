# %%
# !pip install -r "/content/drive/MyDrive/Colab Notebooks/LEVX_1km/requirements.txt"

# %%
# !pip install lazypredict

# %%
import plotly.express as px
import pandas as pd
import numpy as np
coor = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/LEPP/input_files/distan_lat42.77lon-1.647p3R12Km.csv")
px.set_mapbox_access_token("pk.eyJ1IjoiZ3JhbmFudHVpbiIsImEiOiJja3B4dGU4OTkwMTFmMm9ycnNhMjJvaGJqIn0.VWzx_PkD9A5cSUVsn_ijCA")
px.scatter_mapbox(coor, hover_data=['distance'],lat='lat', lon='lon',color='distance', title="Nearest points",
                           color_continuous_scale=px.colors.cyclical.IceFire,)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7025542c-72fc-49e5-a39c-dfcd6a652230" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7025542c-72fc-49e5-a39c-dfcd6a652230")) {                    Plotly.newPlot(                        "7025542c-72fc-49e5-a39c-dfcd6a652230",                        [{"customdata":[[4.81],[7.44],[11.73]],"hovertemplate":"lat=%{lat}<br>lon=%{lon}<br>distance=%{marker.color}<extra></extra>","lat":[42.813004296871526,42.70627064445584,42.79698251897537],"legendgroup":"","lon":[-1.653423261789812,-1.6751004368802438,-1.5079654643891909],"marker":{"color":[4.81,7.44,11.73],"coloraxis":"coloraxis"},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outli ...

# %%
station = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/LEPP/input_files/LEPP2018.csv",
                          usecols =["time","wxcodes_o"],
                          parse_dates=["time"]).dropna().set_index("time")

pd.options.display.max_rows = 999
print("Weather frequencies\n")
station["wxcodes_o"].value_counts(normalize=True).map(lambda n: '{:.2%}'.format(n))
# Out:
# Weather frequencies
# M                 85.30%
# -RA                5.22%
# BR                 1.67%
# FG                 1.38%
# RA                 0.97%
# BCFG               0.61%
# -RA BR             0.36%
# VCFG               0.32%
# BR BCFG            0.31%
# FZFG               0.27%
# VCTS               0.25%
# TS                 0.24%
# RA BR              0.23%
# -SHRA              0.23%
# -TSRA              0.21%
# -SN                0.21%
# -DZ                0.20%
# -UP                0.20%
# SHRA               0.18%
# SN                 0.16%
# TSRA               0.10%
# VCSH               0.07%
# -DZ BR             0.07%
# BCFG BR            0.07%
# TS SHRA            0.06%
# +RA                0.06%
# -SNRA              0.06%
# UP                 0.06%
# TS -SHRA           0.05%
# RASN               0.05%
# SN FZFG            0.05%
# +SHRA              0.04%
# BR -RA             0.04%
# -RA FG             0.04%
# BR VCFG            0.03%
# -SN FZFG           0.03%
# -FZUP BR           0.03%
# VCTS -SHRA         0.03%
# DZ                 0.03%
# -UP BR             0.03%
# TS +SHRA           0.03%
# -RASN              0.03%
# TS VCSH            0.02%
# VCSH -RA           0.02%
# SNRA               0.02%
# -SN BCFG           0.02%
# VCTS SHRA          0.02%
# -DZRA              0.02%
# SHRA VCTS          0.02%
# -RA VCTS           0.02%
# -RA VCFG           0.02%
# PRFG               0.02%
# VCTS VCSH          0.02%
# BCFG MIFG          0.02%
# -SHRA VCTS         0.01%
# TS -RA             0.01%
# PRFG BCFG MIFG     0.01%
# SHRAGS             0.01%
# VCTS RA            0.01%
# -FZRA              0.01%
# VCSH RA            0.01%
# BR PRFG            0.01%
# MIFG BCFG          0.01%
# BR -DZ             0.01%
# PRFG BR            0.01%
# -DZRA BR           0.01%
# -RA BR BCFG        0.01%
# TS RA              0.01%
# PRFG BCFG BR       0.01%
# SN BCFG            0.01%
# TSRAGR             0.01%
# HZ                 0.01%
# MIFG               0.01%
# +TSRA              0.01%
# +RA BR             0.01%
# SHRASN             0.01%
# -SN BR             0.01%
# -UP BR BCFG        0.01%
# -RADZ              0.01%
# -RADZ BR           0.01%
# FZUP               0.01%
# MIFG VCFG          0.01%
# Name: wxcodes_o, dtype: object

# %%
#label br/fg if weather code contains FG or BR

station["brfg_l"] = "No BR/FG"
mask = station['wxcodes_o'].str.contains("BR")
# time                               ...
# 2018-01-01 01:00:00  24224.912109  ...    0.0 -0.001094  0.000000   0.0   0.0
# 2018-01-01 02:00:00  24224.343750  ...    0.0  0.001953  0.000000   0.0   0.0
# 2018-01-01 03:00:00  24221.205078  ...    0.0 -0.004102  0.000000   0.0   0.0
# 2018-01-01 04:00:00  24219.220703  ...    0.0 -0.002734  0.000000   0.0   0.0
# 2018-01-01 05:00:00  24218.425781  ...    0.0  0.001211  0.000000   0.0   0.0
# ...                           ...  ...    ...       ...       ...   ...   ...
# 2018-12-30 19:00:00  24036.539062  ...    0.0  0.000348  0.171875   0.0   0.0
# 2018-12-30 20:00:00  24035.166016  ...    0.0  0.000320  0.101562   0.0   0.0
# 2018-12-30 21:00:00  24036.269531  ...    0.0 -0.000219  0.062500   0.0   0.0
# 2018-12-30 22:00:00  24233.855469  ...    0.0 -0.000383  0.054688   0.0   0.0
# 2018-12-30 23:00:00  24037.146484  ...    0.0 -0.000687  0.000000   0.0   0.0
#
#                          cft2      HGT5002      HGT8502       T5002  \
# time
# 2018-01-01 01:00:00  0.000000  5483.839844  1544.834961  244.594223
# 2018-01-01 02:00:00  0.000000  5499.091797  1549.441040  245.285736
# 2018-01-01 03:00:00  0.000000  5511.755859  1552.350952  245.793243
# 2018-01-01 04:00:00  0.000000  5524.407227  1558.574951  246.264526
# 2018-01-01 05:00:00  0.000000  5532.286133  1559.514038  246.827194
# ...                       ...          ...          ...         ...
# 2018-12-30 19:00:00  0.171875  5717.753906  1633.006958  253.165436
# 2018-12-30 20:00:00  0.101562  5719.474121  1634.531006  253.151443
# 2018-12-30 21:00:00  0.062500  5722.835938  1636.921021  253.225250
# 2018-12-30 22:00:00  0.054688  5726.907227  1641.451050  253.275436
# 2018-12-30 23:00:00  0.000000  5727.846191  1642.765991  253.270370
#
#                           T8502
# time
# 2018-01-01 01:00:00  272.421326
# 2018-01-01 02:00:00  272.807495
# 2018-01-01 03:00:00  273.134460
# 2018-01-01 04:00:00  273.393463
# 2018-01-01 05:00:00  273.539368
# ...                         ...
# 2018-12-30 19:00:00  283.871216
# 2018-12-30 20:00:00  283.921692
# 2018-12-30 21:00:00  284.142029
# 2018-12-30 22:00:00  284.153473
# 2018-12-30 23:00:00  283.821564
#
# [8328 rows x 76 columns]

# %%
import seaborn as sns
sns.set_theme(style="ticks")

sns.pairplot(df_all1k[["brfg_l","rh0","visibility0","cfl0"]].sample(100), hue="brfg_l");

# %%
from sklearn.decomposition import PCA

df_pca = pd.DataFrame(PCA(n_components=3).fit_transform(df_all1k.iloc[:,1:]),
                                                        index =df_all1k.index)
df_pca["brfg_l"] = df_all1k.brfg_l
sns.pairplot(df_pca.sample(100), hue="brfg_l");

# %%
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyClassifier

# X and Y
Y = df_all1k.brfg_l
X = df_all1k.iloc[:,1:]

X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, )


multiple_model = LazyClassifier(verbose =0, ignore_warnings = True,predictions=True)
models,predictions = multiple_model.fit(X_train,X_test,y_train,y_test)
# Out:
# 100%|██████████| 29/29 [00:38<00:00,  1.33s/it]

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LabelPropagation                   0.87               0.79    None      0.87
# LabelSpreading                     0.87               0.79    None      0.87
# LGBMClassifier                     0.89               0.77    None      0.89
# ExtraTreesClassifier               0.90               0.77    None      0.89
# KNeighborsClassifier               0.87               0.77    None      0.87
# RandomForestClassifier             0.89               0.76    None      0.89
# BaggingClassifier                  0.87               0.76    None      0.87
# QuadraticDiscriminantAnalysis      0.78               0.75    None      0.80
# GaussianNB                         0.75               0.74    None      0.77
# BernoulliNB                        0.76               0.74    None      0.78
# NearestCentroid                    0.76               0.73    None      0.78
# DecisionTreeClassifier             0.84               0.73    None      0.83
# AdaBoostClassifier                 0.86               0.71    None      0.85
# ExtraTreeClassifier                0.82               0.70    None      0.82
# LinearDiscriminantAnalysis         0.85               0.70    None      0.84
# LogisticRegression                 0.85               0.69    None      0.84
# CalibratedClassifierCV             0.85               0.69    None      0.84
# LinearSVC                          0.85               0.68    None      0.84
# XGBClassifier                      0.87               0.68    None      0.85
# SVC                                0.87               0.68    None      0.85
# Perceptron                         0.78               0.66    None      0.78
# RidgeClassifierCV                  0.85               0.65    None      0.83
# RidgeClassifier                    0.85               0.65    None      0.83
# PassiveAggressiveClassifier        0.79               0.60    None      0.78
# SGDClassifier                      0.81               0.59    None      0.78
# DummyClassifier                    0.81               0.50    None      0.73
#
#                                Time Taken
# Model
# LabelPropagation                     6.27
# LabelSpreading                       8.62
# LGBMClassifier                       0.85
# ExtraTreesClassifier                 1.52
# KNeighborsClassifier                 0.94
# RandomForestClassifier               6.08
# BaggingClassifier                    4.38
# QuadraticDiscriminantAnalysis        0.22
# GaussianNB                           0.08
# BernoulliNB                          0.12
# NearestCentroid                      0.14
# DecisionTreeClassifier               0.79
# AdaBoostClassifier                   3.88
# ExtraTreeClassifier                  0.08
# LinearDiscriminantAnalysis           0.21
# LogisticRegression                   0.35
# CalibratedClassifierCV               5.73
# LinearSVC                            1.51
# XGBClassifier                        2.49
# SVC                                  4.97
# Perceptron                           0.15
# RidgeClassifierCV                    0.24
# RidgeClassifier                      0.16
# PassiveAggressiveClassifier          0.15
# SGDClassifier                        0.20
# DummyClassifier                      0.06

# %% [markdown]
# **Meteorological model independent variables X**

# %%
df_all1k.iloc[:,1:].columns
# Out:
# Index(['dir0', 'snow_prec0', 'snowlevel0', 'mod0', 'wind_gust0', 'mslp0',
#        'temp0', 'rh0', 'visibility0', 'lhflx0', 'lwflx0', 'conv_prec0',
#        'prec0', 'swflx0', 'shflx0', 'cape0', 'cin0', 'cfh0', 'cfl0', 'cfm0',
#        'cft0', 'HGT5000', 'HGT8500', 'T5000', 'T8500', 'dir1', 'snow_prec1',
#        'snowlevel1', 'mod1', 'wind_gust1', 'mslp1', 'temp1', 'rh1',
#        'visibility1', 'lhflx1', 'lwflx1', 'conv_prec1', 'prec1', 'swflx1',
#        'shflx1', 'cape1', 'cin1', 'cfh1', 'cfl1', 'cfm1', 'cft1', 'HGT5001',
#        'HGT8501', 'T5001', 'T8501', 'dir2', 'snow_prec2', 'snowlevel2', 'mod2',
#        'wind_gust2', 'mslp2', 'temp2', 'rh2', 'visibility2', 'lhflx2',
#        'lwflx2', 'conv_prec2', 'prec2', 'swflx2', 'shflx2', 'cape2', 'cin2',
#        'cfh2', 'cfl2', 'cfm2', 'cft2', 'HGT5002', 'HGT8502', 'T5002', 'T8502'],
#       dtype='object')

# %% [markdown]
# **ML LGBMClassifier. Samples 10. Heidke Skill score. Significance level (alpha) = 0.01 for normality test of HSS samples**

# %%
from lightgbm.sklearn import LGBMClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report
from scipy.stats import shapiro

#random seed 1
np.random.seed(31)

# X and Y
Y = df_all1k.brfg_l
X = df_all1k.iloc[:,1:]

# loop random
HSS = []
for t in range (0,10):

  #split variables
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, )

  # Resample
  X_res, y_res = SMOTE().fit_resample(X_train,y_train)

  #train model
  ml_model = LGBMClassifier(n_estimators=200).fit(X_res,y_res)

  #Confusion matrix
  print("\nConfusion matrix (Machine Learning)\n")

  cm = pd.crosstab(y_test, ml_model.predict(X_test),margins=True,)
  print(cm)
  a = cm.values[0,0]
  b = cm.values[1,0]
  c = cm.values[0,1]
  d = cm.values[1,1]
  HSS.append(2*(a*d-b*c)/((a+c)*(c+d)+(a+b)*(b+d)))
  print("Heidke Skill Score:",round(HSS[t],2))

  #quality report
  print("\nQuality report (Machine Learning)\n")
  print(pd.DataFrame(classification_report(y_test, ml_model.predict(X_test),output_dict=True)).T)

print("\nHSS stadistics")
# if p-value is lower than 5%, we can reject the null hypothesis of the normality of the dataset

print(pd.DataFrame(HSS,columns=["HSS"]).describe())

#sample less 5000
sta, p = shapiro(HSS)
print("\np value:",p)
#significance level alpha=0.01
alpha = 0.01
if p>alpha:
  print("Accept null hypothesis: normal distribution variable HSS in the samples")
else:
  print("Reject null Hypothesis. Alternative hypothesis variable HSS no normal distribution in samples")  

pd.DataFrame(HSS,columns=["HSS"]).hist();
# Out:
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        56        31    87
# No BR/FG     25      1554  1579
# All          81      1585  1666
# Heidke Skill Score: 0.65
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.69    0.64      0.67    87.00
# No BR/FG           0.98    0.98      0.98  1579.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.84    0.81      0.82  1666.00
# weighted avg       0.97    0.97      0.97  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        53        27    80
# No BR/FG     22      1564  1586
# All          75      1591  1666
# Heidke Skill Score: 0.67
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.71    0.66      0.68    80.00
# No BR/FG           0.98    0.99      0.98  1586.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.84    0.82      0.83  1666.00
# weighted avg       0.97    0.97      0.97  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        49        36    85
# No BR/FG     14      1567  1581
# All          63      1603  1666
# Heidke Skill Score: 0.65
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.78    0.58      0.66    85.00
# No BR/FG           0.98    0.99      0.98  1581.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.88    0.78      0.82  1666.00
# weighted avg       0.97    0.97      0.97  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        50        32    82
# No BR/FG     19      1565  1584
# All          69      1597  1666
# Heidke Skill Score: 0.65
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.72    0.61      0.66    82.00
# No BR/FG           0.98    0.99      0.98  1584.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.85    0.80      0.82  1666.00
# weighted avg       0.97    0.97      0.97  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        42        35    77
# No BR/FG     32      1557  1589
# All          74      1592  1666
# Heidke Skill Score: 0.54
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.57    0.55      0.56    77.00
# No BR/FG           0.98    0.98      0.98  1589.00
# accuracy           0.96    0.96      0.96     0.96
# macro avg          0.77    0.76      0.77  1666.00
# weighted avg       0.96    0.96      0.96  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        52        34    86
# No BR/FG     19      1561  1580
# All          71      1595  1666
# Heidke Skill Score: 0.65
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.73    0.60      0.66    86.00
# No BR/FG           0.98    0.99      0.98  1580.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.86    0.80      0.82  1666.00
# weighted avg       0.97    0.97      0.97  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        58        23    81
# No BR/FG     28      1557  1585
# All          86      1580  1666
# Heidke Skill Score: 0.68
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.67    0.72      0.69    81.00
# No BR/FG           0.99    0.98      0.98  1585.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.83    0.85      0.84  1666.00
# weighted avg       0.97    0.97      0.97  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        52        31    83
# No BR/FG     27      1556  1583
# All          79      1587  1666
# Heidke Skill Score: 0.62
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.66    0.63      0.64    83.00
# No BR/FG           0.98    0.98      0.98  1583.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.82    0.80      0.81  1666.00
# weighted avg       0.96    0.97      0.96  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        50        30    80
# No BR/FG     21      1565  1586
# All          71      1595  1666
# Heidke Skill Score: 0.65
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.70    0.62      0.66    80.00
# No BR/FG           0.98    0.99      0.98  1586.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.84    0.81      0.82  1666.00
# weighted avg       0.97    0.97      0.97  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        63        23    86
# No BR/FG     26      1554  1580
# All          89      1577  1666
# Heidke Skill Score: 0.7
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.71    0.73      0.72    86.00
# No BR/FG           0.99    0.98      0.98  1580.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.85    0.86      0.85  1666.00
# weighted avg       0.97    0.97      0.97  1666.00
#
# HSS stadistics
#         HSS
# count 10.00
# mean   0.64
# std    0.04
# min    0.54
# 25%    0.65
# 50%    0.65
# 75%    0.66
# max    0.70
#
# p value: 0.022913705557584763
# Accept null hypothesis: normal distribution variable HSS in the samples

# %% [markdown]
# **Add time features**

# %%
df_all1k["hour"] = df_all1k.index.hour
df_all1k["month"] = df_all1k.index.month
df_all1k["dayofyear"] = df_all1k.index.dayofyear
df_all1k["weekofyear"] = df_all1k.index.isocalendar().week.astype(int)

# %%
df_all1k.iloc[:,1:].columns
# Out:
# Index(['dir0', 'snow_prec0', 'snowlevel0', 'mod0', 'wind_gust0', 'mslp0',
#        'temp0', 'rh0', 'visibility0', 'lhflx0', 'lwflx0', 'conv_prec0',
#        'prec0', 'swflx0', 'shflx0', 'cape0', 'cin0', 'cfh0', 'cfl0', 'cfm0',
#        'cft0', 'HGT5000', 'HGT8500', 'T5000', 'T8500', 'dir1', 'snow_prec1',
#        'snowlevel1', 'mod1', 'wind_gust1', 'mslp1', 'temp1', 'rh1',
#        'visibility1', 'lhflx1', 'lwflx1', 'conv_prec1', 'prec1', 'swflx1',
#        'shflx1', 'cape1', 'cin1', 'cfh1', 'cfl1', 'cfm1', 'cft1', 'HGT5001',
#        'HGT8501', 'T5001', 'T8501', 'dir2', 'snow_prec2', 'snowlevel2', 'mod2',
#        'wind_gust2', 'mslp2', 'temp2', 'rh2', 'visibility2', 'lhflx2',
#        'lwflx2', 'conv_prec2', 'prec2', 'swflx2', 'shflx2', 'cape2', 'cin2',
#        'cfh2', 'cfl2', 'cfm2', 'cft2', 'HGT5002', 'HGT8502', 'T5002', 'T8502',
#        'hour', 'month', 'dayofyear', 'weekofyear'],
#       dtype='object')

# %%
# X and Y
Y = df_all1k.brfg_l
X = df_all1k.iloc[:,1:]

X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, )

multiple_model = LazyClassifier(verbose =0, ignore_warnings = True,predictions=True)
models,predictions = multiple_model.fit(X_train,X_test,y_train,y_test)
models
# Out:
# 100%|██████████| 29/29 [00:34<00:00,  1.19s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# QuadraticDiscriminantAnalysis      0.83               0.86    None      0.87
# LabelPropagation                   0.95               0.83    None      0.96
# LabelSpreading                     0.95               0.83    None      0.96
# ExtraTreesClassifier               0.98               0.80    None      0.98
# DecisionTreeClassifier             0.96               0.79    None      0.96
# LGBMClassifier                     0.98               0.79    None      0.97
# NearestCentroid                    0.68               0.77    None      0.77
# BaggingClassifier                  0.97               0.77    None      0.97
# RandomForestClassifier             0.98               0.76    None      0.97
# BernoulliNB                        0.71               0.75    None      0.79
# KNeighborsClassifier               0.97               0.74    None      0.97
# ExtraTreeClassifier                0.95               0.73    None      0.95
# GaussianNB                         0.58               0.72    None      0.70
# PassiveAggressiveClassifier        0.87               0.63    None      0.90
# AdaBoostClassifier                 0.95               0.61    None      0.94
# LinearDiscriminantAnalysis         0.94               0.60    None      0.93
# SGDClassifier                      0.94               0.57    None      0.94
# Perceptron                         0.94               0.54    None      0.93
# SVC                                0.95               0.51    None      0.93
# CalibratedClassifierCV             0.95               0.50    None      0.93
# LogisticRegression                 0.95               0.50    None      0.93
# DummyClassifier                    0.95               0.50    None      0.93
# LinearSVC                          0.95               0.50    None      0.93
# RidgeClassifier                    0.95               0.50    None      0.93
# RidgeClassifierCV                  0.95               0.50    None      0.93
#
#                                Time Taken
# Model
# QuadraticDiscriminantAnalysis        0.16
# LabelPropagation                     2.39
# LabelSpreading                       3.15
# ExtraTreesClassifier                 1.28
# DecisionTreeClassifier               0.98
# LGBMClassifier                       2.57
# NearestCentroid                      0.10
# BaggingClassifier                    4.15
# RandomForestClassifier               3.49
# BernoulliNB                          0.10
# KNeighborsClassifier                 0.72
# ExtraTreeClassifier                  0.11
# GaussianNB                           0.12
# PassiveAggressiveClassifier          0.12
# AdaBoostClassifier                   5.80
# LinearDiscriminantAnalysis           0.23
# SGDClassifier                        0.25
# Perceptron                           0.12
# SVC                                  1.44
# CalibratedClassifierCV               4.70
# LogisticRegression                   0.34
# DummyClassifier                      0.10
# LinearSVC                            1.26
# RidgeClassifier                      0.25
# RidgeClassifierCV                    0.32

# %%
from lightgbm.sklearn import LGBMClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report
from scipy.stats import shapiro

#random seed 1
np.random.seed(31)

# X and Y
Y = df_all1k.brfg_l
X = df_all1k.iloc[:,1:]

# loop random
HSS_a = []
for t in range (0,10):

  #split variables
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, )

  # Resample
  X_res, y_res = SMOTE().fit_resample(X_train,y_train)

  #train model
  ml_model = LGBMClassifier(n_estimators=200).fit(X_res,y_res)

  #Confusion matrix
  print("\nConfusion matrix (Machine Learning)\n")

  cm = pd.crosstab(y_test, ml_model.predict(X_test),margins=True,)
  print(cm)
  a = cm.values[0,0]
  b = cm.values[1,0]
  c = cm.values[0,1]
  d = cm.values[1,1]
  HSS_a.append(2*(a*d-b*c)/((a+c)*(c+d)+(a+b)*(b+d)))
  print("Heidke Skill Score:",round(HSS_a[t],2))

  #quality report
  print("\nQuality report (Machine Learning)\n")
  print(pd.DataFrame(classification_report(y_test, ml_model.predict(X_test),output_dict=True)).T)

print("\nHSS stadistics")
# if p-value is lower than 1%, we can reject the null hypothesis of the normality of the dataset

print(pd.DataFrame(HSS_a,columns=["HSS"]).describe())

#sample less 5000
sta, p = shapiro(HSS_a)
print("\np value:",p)

#significance level alpha=0.01
alpha = 0.01
if p>alpha:
  print("Accept null Hypothesis: normal distribution variable HSS in the samples")
else:
  print("Reject null Hypothesis. Alternative hypothesis variable HSS no normal distribution in samples")  

pd.DataFrame(HSS_a,columns=["HSS_a"]).hist();
# Out:
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        52        35    87
# No BR/FG     28      1551  1579
# All          80      1586  1666
# Heidke Skill Score: 0.6
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.65    0.60      0.62    87.00
# No BR/FG           0.98    0.98      0.98  1579.00
# accuracy           0.96    0.96      0.96     0.96
# macro avg          0.81    0.79      0.80  1666.00
# weighted avg       0.96    0.96      0.96  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        48        32    80
# No BR/FG     16      1570  1586
# All          64      1602  1666
# Heidke Skill Score: 0.65
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.75    0.60      0.67    80.00
# No BR/FG           0.98    0.99      0.98  1586.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.87    0.79      0.83  1666.00
# weighted avg       0.97    0.97      0.97  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        54        31    85
# No BR/FG     12      1569  1581
# All          66      1600  1666
# Heidke Skill Score: 0.7
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.82    0.64      0.72    85.00
# No BR/FG           0.98    0.99      0.99  1581.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.90    0.81      0.85  1666.00
# weighted avg       0.97    0.97      0.97  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        51        31    82
# No BR/FG     18      1566  1584
# All          69      1597  1666
# Heidke Skill Score: 0.66
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.74    0.62      0.68    82.00
# No BR/FG           0.98    0.99      0.98  1584.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.86    0.81      0.83  1666.00
# weighted avg       0.97    0.97      0.97  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        46        31    77
# No BR/FG     28      1561  1589
# All          74      1592  1666
# Heidke Skill Score: 0.59
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.62    0.60      0.61    77.00
# No BR/FG           0.98    0.98      0.98  1589.00
# accuracy           0.96    0.96      0.96     0.96
# macro avg          0.80    0.79      0.80  1666.00
# weighted avg       0.96    0.96      0.96  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        55        31    86
# No BR/FG     20      1560  1580
# All          75      1591  1666
# Heidke Skill Score: 0.67
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.73    0.64      0.68    86.00
# No BR/FG           0.98    0.99      0.98  1580.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.86    0.81      0.83  1666.00
# weighted avg       0.97    0.97      0.97  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        56        25    81
# No BR/FG     28      1557  1585
# All          84      1582  1666
# Heidke Skill Score: 0.66
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.67    0.69      0.68    81.00
# No BR/FG           0.98    0.98      0.98  1585.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.83    0.84      0.83  1666.00
# weighted avg       0.97    0.97      0.97  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        54        29    83
# No BR/FG     25      1558  1583
# All          79      1587  1666
# Heidke Skill Score: 0.65
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.68    0.65      0.67    83.00
# No BR/FG           0.98    0.98      0.98  1583.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.83    0.82      0.82  1666.00
# weighted avg       0.97    0.97      0.97  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        52        28    80
# No BR/FG     18      1568  1586
# All          70      1596  1666
# Heidke Skill Score: 0.68
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.74    0.65      0.69    80.00
# No BR/FG           0.98    0.99      0.99  1586.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.86    0.82      0.84  1666.00
# weighted avg       0.97    0.97      0.97  1666.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        65        21    86
# No BR/FG     17      1563  1580
# All          82      1584  1666
# Heidke Skill Score: 0.76
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.79    0.76      0.77    86.00
# No BR/FG           0.99    0.99      0.99  1580.00
# accuracy           0.98    0.98      0.98     0.98
# macro avg          0.89    0.87      0.88  1666.00
# weighted avg       0.98    0.98      0.98  1666.00
#
# HSS stadistics
#         HSS
# count 10.00
# mean   0.66
# std    0.05
# min    0.59
# 25%    0.65
# 50%    0.66
# 75%    0.68
# max    0.76
#
# p value: 0.4798740744590759
# Accept null Hypothesis: normal distribution variable HSS in the samples

# %% [markdown]
# **Test association between observed variable and machine learning forecast (Pearson’s chi square test). Significance level (alpha) = 0.01**

# %%
from scipy.stats import chi2_contingency

print("Last confusion matrix\n")
print(cm.iloc[0:2,0:2])

#stadistic(sta), pvalue (p), degrees of freedom (dof) and expected values (exp)
sta, p, dof, exp = chi2_contingency(cm.iloc[0:2,0:2])

#degrees of freedoom (rows-1)*(columns-1) to test associationbetween two variables
alpha = 0.01
print('\np-value:',p)
print('Significance level:',alpha)
print('Degres of of freedom: ',dof)
print("Stadistic",sta)

if p<=alpha:
    print("Reject H0,There is an association between machine learning forecast and observed values")
else:
    print("Retain H0,There is no association between machine learning forecast and observed values")
# Out:
# Last confusion matrix
#
# col_0     BR/FG  No BR/FG
# brfg_l
# BR/FG        65        21
# No BR/FG     17      1563
#
# p-value: 5.912388604111063e-209
# Significance level: 0.01
# Degres of of freedom:  1
# Stadistic 951.614629989888
# Reject H0,There is an association between machine learning forecast and observed values

# %% [markdown]
# **T test two related samples. This is a test for the null hypothesis that two related samples have identical HSS means. Alternative hypothesis the mean of the distribution underlying the sample without time variables is less than the mean of the distribution underlying the sample with time variables. Significance level (alpha) = 0.01**

# %%
from scipy import stats

alpha = 0.01
sta, p_value = stats.ttest_rel(HSS, HSS_a, alternative="less")

print("\nmeans without time variables:", np.round(HSS,2))
print("\nmeans with time variables:", np.round(HSS_a,2))

print("\nalpha: ",alpha)

print("\np_value point: ",p_value)
if p_value < alpha:    
    print("\nwe are rejecting null hypothesis  H0: HHS mean without time variables = HSS mean with time variables")
    print("\nwe are accepting alternative hypothesis: the HSS mean of the sample without time variables inputs is less than the HSS mean of the sample with time variables inputs")
else:
    print("\nwe are accepting null hypothesis:  H0: HSS mean without time variables = HSS mean with time variables ")
# Out:
# means without time variables: [0.65 0.67 0.65 0.65 0.54 0.65 0.68 0.62 0.65 0.7 ]
#
# means with time variables: [0.6  0.65 0.7  0.66 0.59 0.67 0.66 0.65 0.68 0.76]
#
# alpha:  0.01
#
# p_value point:  0.0675863899616753
#
# we are accepting null hypothesis:  H0: HSS mean without time variables = HSS mean with time variables

# %%
import pickle
from sklearn.pipeline import Pipeline

estimators = [('ml_model', ml_model)]
pipe = Pipeline(estimators)
print(pipe)
al_file={"x_var":X.columns,"coor":coor,"pipe":pipe}
pickle.dump(al_file, open("brfg_LEPP_d0.al", 'wb'))
# Out:
# Pipeline(steps=[('ml_model', LGBMClassifier(n_estimators=200))])

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.24.1

# %% [markdown]
# **Best algorithm too heavy to upload in github!!**

# %%
df_all1k.iloc[:,1:].columns
# Out:
# Index(['dir0', 'snow_prec0', 'snowlevel0', 'mod0', 'wind_gust0', 'mslp0',
#        'temp0', 'rh0', 'visibility0', 'lhflx0', 'lwflx0', 'conv_prec0',
#        'prec0', 'swflx0', 'shflx0', 'cape0', 'cin0', 'cfh0', 'cfl0', 'cfm0',
#        'cft0', 'HGT5000', 'HGT8500', 'T5000', 'T8500', 'dir1', 'snow_prec1',
#        'snowlevel1', 'mod1', 'wind_gust1', 'mslp1', 'temp1', 'rh1',
#        'visibility1', 'lhflx1', 'lwflx1', 'conv_prec1', 'prec1', 'swflx1',
#        'shflx1', 'cape1', 'cin1', 'cfh1', 'cfl1', 'cfm1', 'cft1', 'HGT5001',
#        'HGT8501', 'T5001', 'T8501', 'dir2', 'snow_prec2', 'snowlevel2', 'mod2',
#        'wind_gust2', 'mslp2', 'temp2', 'rh2', 'visibility2', 'lhflx2',
#        'lwflx2', 'conv_prec2', 'prec2', 'swflx2', 'shflx2', 'cape2', 'cin2',
#        'cfh2', 'cfl2', 'cfm2', 'cft2', 'HGT5002', 'HGT8502', 'T5002', 'T8502',
#        'hour', 'month', 'dayofyear', 'weekofyear'],
#       dtype='object')

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report

#random seed 1
np.random.seed(31)

# X and Y
Y = df_all1k.brfg_l
X = df_all1k.iloc[:,1:]

# loop random
HSS_b = []
for t in range (0,10):
  #split variables
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.15, )

  # Resample
  X_res, y_res = SMOTE().fit_resample(X_train,y_train)

  ml_model = ExtraTreesClassifier(n_estimators=150).fit(X_res,y_res)

  #Confussion matrix

  print("\nConfusion matrix (Machine Learning)\n")

  cm = pd.crosstab(y_test, ml_model.predict(X_test),margins=True,)
  print(cm)
  a = cm.values[0,0]
  b = cm.values[1,0]
  c = cm.values[0,1]
  d = cm.values[1,1]
  HSS_b.append(2*(a*d-b*c)/((a+c)*(c+d)+(a+b)*(b+d)))
  print("Heidke Skill Score:",round(HSS_b[t],2))

  #quality report

  print("\nQuality report (Machine Learning)\n")
  print(pd.DataFrame(classification_report(y_test, ml_model.predict(X_test),output_dict=True)).T)

print("\nHSS stadistics")
pd.DataFrame(HSS_b,columns=["HSS"]).describe()
# Out:
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        46        21    67
# No BR/FG     18      1165  1183
# All          64      1186  1250
# Heidke Skill Score: 0.69
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.72    0.69      0.70    67.00
# No BR/FG           0.98    0.98      0.98  1183.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.85    0.84      0.84  1250.00
# weighted avg       0.97    0.97      0.97  1250.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        52        20    72
# No BR/FG      9      1169  1178
# All          61      1189  1250
# Heidke Skill Score: 0.77
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.85    0.72      0.78    72.00
# No BR/FG           0.98    0.99      0.99  1178.00
# accuracy           0.98    0.98      0.98     0.98
# macro avg          0.92    0.86      0.88  1250.00
# weighted avg       0.98    0.98      0.98  1250.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        42        14    56
# No BR/FG     10      1184  1194
# All          52      1198  1250
# Heidke Skill Score: 0.77
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.81    0.75      0.78    56.00
# No BR/FG           0.99    0.99      0.99  1194.00
# accuracy           0.98    0.98      0.98     0.98
# macro avg          0.90    0.87      0.88  1250.00
# weighted avg       0.98    0.98      0.98  1250.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        45        26    71
# No BR/FG     10      1169  1179
# All          55      1195  1250
# Heidke Skill Score: 0.7
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.82    0.63      0.71    71.00
# No BR/FG           0.98    0.99      0.98  1179.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.90    0.81      0.85  1250.00
# weighted avg       0.97    0.97      0.97  1250.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        38        23    61
# No BR/FG      9      1180  1189
# All          47      1203  1250
# Heidke Skill Score: 0.69
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.81    0.62      0.70    61.00
# No BR/FG           0.98    0.99      0.99  1189.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.89    0.81      0.85  1250.00
# weighted avg       0.97    0.97      0.97  1250.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        47        18    65
# No BR/FG      9      1176  1185
# All          56      1194  1250
# Heidke Skill Score: 0.77
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.84    0.72      0.78    65.00
# No BR/FG           0.98    0.99      0.99  1185.00
# accuracy           0.98    0.98      0.98     0.98
# macro avg          0.91    0.86      0.88  1250.00
# weighted avg       0.98    0.98      0.98  1250.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        33        18    51
# No BR/FG     10      1189  1199
# All          43      1207  1250
# Heidke Skill Score: 0.69
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.77    0.65      0.70    51.00
# No BR/FG           0.99    0.99      0.99  1199.00
# accuracy           0.98    0.98      0.98     0.98
# macro avg          0.88    0.82      0.85  1250.00
# weighted avg       0.98    0.98      0.98  1250.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        48        19    67
# No BR/FG     16      1167  1183
# All          64      1186  1250
# Heidke Skill Score: 0.72
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.75    0.72      0.73    67.00
# No BR/FG           0.98    0.99      0.99  1183.00
# accuracy           0.97    0.97      0.97     0.97
# macro avg          0.87    0.85      0.86  1250.00
# weighted avg       0.97    0.97      0.97  1250.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        46        21    67
# No BR/FG     10      1173  1183
# All          56      1194  1250
# Heidke Skill Score: 0.74
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.82    0.69      0.75    67.00
# No BR/FG           0.98    0.99      0.99  1183.00
# accuracy           0.98    0.98      0.98     0.98
# macro avg          0.90    0.84      0.87  1250.00
# weighted avg       0.97    0.98      0.97  1250.00
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG        51        17    68
# No BR/FG     10      1172  1182
# All          61      1189  1250
# Heidke Skill Score: 0.78
#
# Quality report (Machine Learning)
#
#               precision  recall  f1-score  support
# BR/FG              0.84    0.75      0.79    68.00
# No BR/FG           0.99    0.99      0.99  1182.00
# accuracy           0.98    0.98      0.98     0.98
# macro avg          0.91    0.87      0.89  1250.00
# weighted avg       0.98    0.98      0.98  1250.00
#
# HSS stadistics
#         HSS
# count 10.00
# mean   0.73
# std    0.04
# min    0.69
# 25%    0.69
# 50%    0.73
# 75%    0.77
# max    0.78

# %% [markdown]
# **T test two related samples. This is a test for the null hypothesis that two related samples have identical HSS means. Alternative hypothesis the mean of the distribution underlying the sample without time variables is less than the mean of the distribution underlying the sample with time variables. Significance level (alpha) = 0.01**

# %%
from scipy import stats

alpha = 0.01
sta, p_value = stats.ttest_rel(HSS_a, HSS_b, alternative="less")

print("\nHSS LGBMClassifier:", np.round(HSS_a,2))
print("\nHSS ExtraTreesClassifier:", np.round(HSS_b,2))

print("\nalpha: ",alpha)

print("\np_value point: ",p_value)
if p_value < alpha:    
    print("\nwe are rejecting null hypothesis  H0: HHS mean ExtraTreesClassifier = HSS mean with LGBMClassifier")
    print("\nwe are accepting alternative hypothesis: the HSS mean of the sample LGBMClassifier is less than the HSS mean of the sample with ExtraTreesClassifier")
else:
    print("\nwe are accepting null hypothesis:  H0: HSS mean LGBMClassifier = HSS mean with ExtraTreesClassifier")
# Out:
# HSS LGBMClassifier: [0.6  0.65 0.7  0.66 0.59 0.67 0.66 0.65 0.68 0.76]
#
# HSS ExtraTreesClassifier: [0.69 0.77 0.77 0.7  0.69 0.77 0.69 0.72 0.74 0.78]
#
# alpha:  0.01
#
# p_value point:  5.661497500889456e-05
#
# we are rejecting null hypothesis  H0: HHS mean ExtraTreesClassifier = HSS mean with LGBMClassifier
#
# we are accepting alternative hypothesis: the HSS mean of the sample LGBMClassifier is less than the HSS mean of the sample with ExtraTreesClassifier

# %% [markdown]
# **PCA components**

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler

#random seed 1
np.random.seed(31)

# X and Y
Y = df_all1k.brfg_l
X = df_all1k.iloc[:,1:]

# loop random
HSS_pca = []
for t in range (0,10):
  #split variables
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.15, )

  # Resample
  X_res, y_res = SMOTE().fit_resample(X_train,y_train)

  #scaler
  sc = StandardScaler().fit(X_res)
  X_sc = sc.transform(X_res)

  #PCA
  n_components = len(X.columns)
  pca = PCA(n_components).fit(X_sc)
  X_pca = pca.transform(X_sc)

  #machine learning model
  #ml_model = ExtraTreesClassifier(n_estimators=150).fit(X_pca,y_res)
  ml_model = MLPClassifier(hidden_layer_sizes=(100,50,10)).fit(X_pca,y_res)
  
  #Confusion matrix
  print("\nConfusion matrix (Machine Learning)\n")

  y_pca = pca.transform(sc.transform(X_test))
  cm = pd.crosstab(y_test, ml_model.predict(y_pca),margins=True,)
  print(cm)
  a = cm.values[0,0]
  b = cm.values[1,0]
  c = cm.values[0,1]
  d = cm.values[1,1]
  HSS_pca.append(2*(a*d-b*c)/((a+c)*(c+d)+(a+b)*(b+d)))
  print("Heidke Skill Score:",round(HSS_pca[t],2))

  #quality report

  print("\nQuality report (Machine Learning)\n")
  print(pd.DataFrame(classification_report(y_test, ml_model.predict(y_pca),output_dict=True)).T)

print("\nHSS stadistics")
pd.DataFrame(HSS_pca,columns=["HSS_pca"]).describe()
# Out:
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       287       150   437
# No BR/FG    179      1855  2034
# All         466      2005  2471
# Heidke Skill Score: 0.55
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0.615880  0.656751  0.635659   437.000000
# No BR/FG       0.925187  0.911996  0.918544  2034.000000
# accuracy       0.866856  0.866856  0.866856     0.866856
# macro avg      0.770533  0.784373  0.777102  2471.000000
# weighted avg   0.870486  0.866856  0.868516  2471.000000
#
# Confusion matrix (Machine Learning)
#
# col_0     BR/FG  No BR/FG   All
# brfg_l
# BR/FG       288       173   461
# No BR/FG    208      1802  2010
# All         496      1975  2471
# Heidke Skill Score: 0.51
#
# Quality report (Machine Learning)
#
#               precision    recall  f1-score      support
# BR/FG          0